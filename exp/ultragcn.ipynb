# %% [markdown]
# # Ultra Experiment

# %% [markdown]
# ## 1. Clone repo & Install dependencies

# %%
# !git clone https://github.com/leonas-bigdata/ultragcn.git
# Out:
# Cloning into 'ultragcn'...
# remote: Enumerating objects: 539, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 539 (delta 67), reused 59 (delta 56), pack-reused 445 (from 2)
# Receiving objects: 100% (539/539), 57.16 MiB | 32.66 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %%
# %cd ultragcn/matching/gnn/UltraGCN
# Out:
# /kaggle/working/ultragcn/matching/gnn/UltraGCN

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Run experiments

# %% [markdown]
# **Yelp2018**

# %%
# First experiment
# !python main.py --config_file ./config/ultragcn_yelp18_m1.ini
# Out:
# 2026-04-08 02:29:16.151104: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775615356.535633     117 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775615356.649095     117 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775615357.640205     117 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Second experiment
# !python main.py --config_file ./config/ultragcn_yelp18_m1.ini
# Out:
# 2026-04-08 03:23:31.804564: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775618611.827697    1146 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775618611.835247    1146 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775618611.855114    1146 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Third experiment
# !python main.py --config_file ./config/ultragcn_yelp18_m1.ini
# Out:
# 2026-04-08 04:24:38.496122: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775622278.520073    2044 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775622278.528096    2044 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775622278.551290    2044 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **AmazonBook**

# %%
# First experiment
# !python main.py --config_file ./config/ultragcn_amazonbooks_m1.ini
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ^C

# %% [markdown]
# **Gowalla**

# %%
# First experiment
# !python main.py --config_file ./config/ultragcn_gowalla_m1.ini
# Out:
# 2026-04-08 06:39:09.997034: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775630350.215862     133 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775630350.279967     133 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775630350.796236     133 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Second experiment
# !python main.py --config_file ./config/ultragcn_gowalla_m1.ini
# Out:
# 2026-04-09 04:44:28.066924: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775709868.422170     112 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775709868.524211     112 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775709869.379123     112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Third experiment
# !python main.py --config_file ./config/ultragcn_gowalla_m1.ini

# %% [markdown]
# **MovieLens1M**

# %%
# First experiment
# !python main.py --config_file ./config/ultragcn_movielens1m_m1.ini
# Out:
# 2026-04-09 01:58:47.043997: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775699927.231665     111 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775699927.284446     111 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775699927.729127     111 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Second experiment
# !python main.py --config_file ./config/ultragcn_movielens1m_m1.ini
# Out:
# 2026-04-09 02:29:26.075309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775701766.097754    1993 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775701766.105572    1993 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775701766.125999    1993 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Third experiment
# !python main.py --config_file ./config/ultragcn_movielens1m_m1.ini
# Out:
# 2026-04-09 02:54:50.635106: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775703290.658624    3891 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775703290.666169    3891 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775703290.685887    3891 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **Gitstar**
