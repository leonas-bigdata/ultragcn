# %% [markdown]
# # UltraGCN Rerun 2
#
# This notebook is used for conducting experiment on UltraGCN model, due to quota limit on Kaggle, we have switched to run on Google Colab for the Gowalla, AmazonBook and Gitstar dataset,
#
# **Note**: Gowalla will be run in the `ultragcn_rerun_1.ipynb` file. This book will focus on AmazonBook and Gitstar

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/model_exp/UltraGCN
# Out:
# /content/drive/MyDrive/model_exp/UltraGCN

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (26.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.6)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5

# %% [markdown]
# **Amazon Book**

# %%
# !python main.py --config_file ./config/ultragcn_amazonbooks_m1.ini
# Out:
# 2026-04-10 10:43:35.645618: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-10 10:43:35.663157: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775817815.685576    2570 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775817815.692890    2570 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775817815.711902    2570 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817815.711930    2570 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817815.711933    2570 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817815.711935    2570 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-10 10:43:35.716772: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ###################### UltraGCN ######################
# Loading Configuration...
# Computing \Omega for the item-item graph...
# i-i constraint matrix 0 ok
# i-i constraint matrix 15000 ok
# i-i constraint matrix 30000 ok
# i-i constraint matrix 45000 ok
# i-i constraint matrix 60000 ok
# i-i constraint matrix 75000 ok
# i-i constraint matrix 90000 ok
# Computation \Omega OK!
# store object in path = ./amazon_ii_neighbor_mat ok
# store object in path = ./amazon_ii_constraint_mat ok
# Load Configuration OK, show them below
# Configuration:
# {'embedding_dim': 64, 'ii_neighbor_num': 10, 'model_save_path': './ultragcn_amazon.pt', 'max_epoch': 2000, 'enable_tensorboard': True, 'initial_weight': 0.0001, 'dataset': 'amazon', 'gpu': '0', 'device': device(type='cuda', index=0), 'lr': 0.001, 'batch_size': 1024, 'early_stop_epoch': 15, 'w1': 1e-08, 'w2': 1.0, 'w3': 1.0, 'w4': 1e-08, 'negative_num': 500, 'negative_weight': 500.0, 'gamma': 0.0001, 'lambda': 2.75, 'sampling_sift_pos': False, 'test_batch_size': 2048, 'topk': 20, 'user_num': 52643, 'item_num': 91599}
# Total training batches = 2325
# EPOCH[0/2000] loss:1918.563 | F1:0.0023 | P:0.0017 | R:0.0035 | NDCG:0.0030 | T:35.52s | RAM:20991.4MB | CPU:29.6% | VRAM:155.6MB
# EPOCH[5/2000] loss:977.992 | F1:0.0024 | P:0.0018 | R:0.0038 | NDCG:0.0031 | T:34.35s | RAM:21035.2MB | CPU:27.6% | VRAM:163.7MB
# EPOCH[10/2000] loss:795.691 | F1:0.0169 | P:0.0123 | R:0.0269 | NDCG:0.0226 | T:34.15s | RAM:21061.7MB | CPU:27.5% | VRAM:163.7MB
# EPOCH[15/2000] loss:715.733 | F1:0.0282 | P:0.0203 | R:0.0462 | NDCG:0.0376 | T:34.07s | RAM:21051.5MB | CPU:27.6% | VRAM:163.7MB
# EPOCH[20/2000] loss:690.323 | F1:0.0333 | P:0.0237 | R:0.0558 | NDCG:0.0455 | T:34.46s | RAM:21068.4MB | CPU:27.6% | VRAM:163.7MB
# EPOCH[25/2000] loss:674.805 | F1:0.0362 | P:0.0257 | R:0.0610 | NDCG:0.0496 | T:34.32s | RAM:21053.8MB | CPU:27.8% | VRAM:163.7MB
# EPOCH[30/2000] loss:662.741 | F1:0.0376 | P:0.0266 | R:0.0637 | NDCG:0.0519 | T:34.39s | RAM:21055.3MB | CPU:27.7% | VRAM:163.7MB
B | CPU:25.4% | VRAM:163.7MB
# EPOCH[118/2000] loss:640.954 | F1:0.0397 | P:0.0281 | R:0.0678 | NDCG:0.0555 | T:34.22s | RAM:21042.6MB | CPU:25.2% | VRAM:163.7MB
# EPOCH[119/2000] loss:656.336 | F1:0.0396 | P:0.0280 | R:0.0677 | NDCG:0.0553 | T:34.33s | RAM:21050.4MB | CPU:25.0% | VRAM:163.7MB
# EPOCH[120/2000] loss:651.961 | F1:0.0397 | P:0.0280 | R:0.0680 | NDCG:0.0555 | T:34.27s | RAM:21031.7MB | CPU:25.4% | VRAM:163.7MB
# EPOCH[121/2000] loss:649.999 | F1:0.0396 | P:0.0280 | R:0.0677 | NDCG:0.0554 | T:34.24s | RAM:21023.1MB | CPU:25.0% | VRAM:163.7MB
# EPOCH[122/2000] loss:653.035 | F1:0.0397 | P:0.0281 | R:0.0679 | NDCG:0.0554 | T:34.31s | RAM:21033.8MB | CPU:25.3% | VRAM:163.7MB
# EPOCH[123/2000] loss:649.804 | F1:0.0397 | P:0.0281 | R:0.0677 | NDCG:0.0552 | T:34.45s | RAM:21040.4MB | CPU:25.0% | VRAM:163.7MB
# EPOCH[124/2000] loss:662.041 | F1:0.0398 | P:0.0281 | R:0.0679 | NDCG:0.0556 | T:34.48s | RAM:21041.7MB | CPU:25.1% | VRAM:163.7MB
# EPOCH[125/2000] loss:657.355 | F1:0.0395 | P:0.0279 | R:0.0674 | NDCG:0.0551 | T:34.47s | RAM:21034.3MB | CPU:25.3% | VRAM:163.7MB
# ##########################################
# Early stop is triggered at 125 epochs.
# Results:
# best epoch = 110, best recall = 0.06826846552975901, best ndcg = 0.055487487711570416
# The best model is saved at ./ultragcn_amazon.pt
#
# Training finished. Total time: 01:44:57
# END

# %% [markdown]
# **GitStar**

# %%
# !python main.py --config_file ./config/ultragcn_gitstart_m1.ini
# Out:
# 2026-04-11 02:12:05.963585: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-11 02:12:05.981137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775873526.003618    2509 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775873526.010978    2509 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775873526.029913    2509 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775873526.029946    2509 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775873526.029949    2509 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775873526.029952    2509 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-11 02:12:06.034751: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ###################### UltraGCN ######################
# Loading Configuration...
# Computing \Omega for the item-item graph...
# i-i constraint matrix 0 ok
# Computation \Omega OK!
# store object in path = ./gitstar_ii_neighbor_mat ok
# store object in path = ./gitstar_ii_constraint_mat ok
# Load Configuration OK, show them below
# Configuration:
# {'embedding_dim': 64, 'ii_neighbor_num': 10, 'model_save_path': './ultragcn_gitstar.pt', 'max_epoch': 2000, 'enable_tensorboard': True, 'initial_weight': 0.0001, 'dataset': 'gitstar', 'gpu': '0', 'device': device(type='cuda', index=0), 'lr': 0.001, 'batch_size': 1024, 'early_stop_epoch': 15, 'w1': 1e-08, 'w2': 1.0, 'w3': 1e-08, 'w4': 1.0, 'negative_num': 800, 'negative_weight': 300.0, 'gamma': 0.0001, 'lambda': 0.0005, 'sampling_sift_pos': False, 'test_batch_size': 2048, 'topk': 20, 'user_num': 6771, 'item_num': 11716}
# Total training batches = 972
# EPOCH[0/2000] loss:45.853 | F1:0.0029 | P:0.0015 | R:0.0306 | NDCG:0.0125 | T:21.42s | RAM:2599.2MB | CPU:15.1% | VRAM:23.7MB
# EPOCH[5/2000] loss:35.045 | F1:0.0032 | P:0.0017 | R:0.0341 | NDCG:0.0131 | T:20.79s | RAM:2579.7MB | CPU:22.6% | VRAM:31.8MB
# EPOCH[10/2000] loss:32.889 | F1:0.0029 | P:0.0015 | R:0.0301 | NDCG:0.0118 | T:20.66s | RAM:2574.6MB | CPU:21.8% | VRAM:31.8MB
# EPOCH[15/2000] loss:32.102 | F1:0.0031 | P:0.0016 | R:0.0323 | NDCG:0.0134 | T:20.67s | RAM:2562.3MB | CPU:22.5% | VRAM:31.8MB
# EPOCH[20/2000] loss:30.217 | F1:0.0039 | P:0.0020 | R:0.0406 | NDCG:0.0179 | T:20.54s | RAM:2574.4MB | CPU:23.1% | VRAM:31.8MB
# EPOCH[25/2000] loss:31.107 | F1:0.0041 | P:0.0022 | R:0.0434 | NDCG:0.0182 | T:20.57s | RAM:2580.4MB | CPU:22.2% | VRAM:31.8MB
# EPOCH[30/2000] loss:29.738 | F1:0.0042 | P:0.0022 | R:0.0446 | NDCG:0.0187 | T:21.29s | RAM:2568.6MB | CPU:22.9% | VRAM:31.8MB
# EPOCH[35/2000] loss:30.783 | F1:0.0044 | P:0.0023 | R:0.0467 | NDCG:0.0192 | T:20.77s | RAM:2572.7MB | CPU:22.8% | VRAM:31.8MB
# EPOCH[40/2000] loss:30.121 | F1:0.0045 | P:0.0024 | R:0.0473 | NDCG:0.0195 | T:20.71s | RAM:2587.9MB | CPU:22.5% | VRAM:31.8MB
# EPOCH[45/2000] loss:32.059 | F1:0.0048 | P:0.0025 | R:0.0502 | NDCG:0.0209 | T:20.73s | RAM:2577.4MB | CPU:22.8% | VRAM:31.8MB
# EPOCH[50/2000] loss:31.275 | F1:0.0047 | P:0.0025 | R:0.0495 | NDCG:0.0209 | T:20.69s | RAM:2590.0MB | CPU:21.7% | VRAM:31.8MB
# EPOCH[51/2000] loss:30.784 | F1:0.0050 | P:0.0026 | R:0.0521 | NDCG:0.0212 | T:20.62s | RAM:2579.6MB | CPU:22.9% | VRAM:31.8MB
# EPOCH[52/2000] loss:31.418 | F1:0.0050 | P:0.0026 | R:0.0524 | NDCG:0.0212 | T:20.62s | RAM:2573.8MB | CPU:22.8% | VRAM:31.8MB
# EPOCH[53/2000] loss:30.514 | F1:0.0049 | P:0.0026 | R:0.0517 | NDCG:0.0218 | T:20.65s | RAM:2585.0MB | CPU:21.8% | VRAM:31.8MB
# EPOCH[54/2000] loss:32.262 | F1:0.0050 | P:0.0026 | R:0.0523 | NDCG:0.0211 | T:20.66s | RAM:2571.1MB | CPU:22.9% | VRAM:31.8MB
# EPOCH[55/2000] loss:30.761 | F1:0.0047 | P:0.0025 | R:0.0490 | NDCG:0.0203 | T:20.72s | RAM:2571.3MB | CPU:22.9% | VRAM:31.8MB
# EPOCH[56/2000] loss:30.925 | F1:0.0050 | P:0.0026 | R:0.0523 | NDCG:0.0213 | T:20.71s | RAM:2599.9MB | CPU:22.1% | VRAM:31.8MB
# EPOCH[57/2000] loss:30.738 | F1:0.0049 | P:0.0026 | R:0.0517 | NDCG:0.0210 | T:20.65s | RAM:2574.5MB | CPU:22.4% | VRAM:31.8MB
# EPOCH[58/2000] loss:32.547 | F1:0.0050 | P:0.0026 | R:0.0529 | NDCG:0.0213 | T:20.70s | RAM:2584.2MB | CPU:22.5% | VRAM:31.8MB
# EPOCH[59/2000] loss:31.598 | F1:0.0051 | P:0.0027 | R:0.0541 | NDCG:0.0216 | T:20.59s | RAM:2587.4MB | CPU:23.0% | VRAM:31.8MB
# EPOCH[60/2000] loss:30.888 | F1:0.0050 | P:0.0026 | R:0.0529 | NDCG:0.0213 | T:20.56s | RAM:2574.2MB | CPU:21.6% | VRAM:31.8MB
# EPOCH[61/2000] loss:30.994 | F1:0.0050 | P:0.0026 | R:0.0520 | NDCG:0.0213 | T:20.68s | RAM:2592.0MB | CPU:22.8% | VRAM:31.8MB
# EPOCH[62/2000] loss:31.755 | F1:0.0049 | P:0.0026 | R:0.0511 | NDCG:0.0210 | T:20.72s | RAM:2563.1MB | CPU:22.6% | VRAM:31.8MB
# EPOCH[63/2000] loss:30.977 | F1:0.0050 | P:0.0026 | R:0.0521 | NDCG:0.0213 | T:20.58s | RAM:2590.3MB | CPU:21.9% | VRAM:31.8MB
# EPOCH[64/2000] loss:31.715 | F1:0.0049 | P:0.0026 | R:0.0518 | NDCG:0.0207 | T:20.76s | RAM:2572.2MB | CPU:22.9% | VRAM:31.8MB
# EPOCH[65/2000] loss:32.274 | F1:0.0051 | P:0.0027 | R:0.0539 | NDCG:0.0219 | T:20.74s | RAM:2580.2MB | CPU:22.5% | VRAM:31.8MB
# EPOCH[66/2000] loss:31.823 | F1:0.0048 | P:0.0025 | R:0.0508 | NDCG:0.0209 | T:20.65s | RAM:2581.1MB | CPU:22.6% | VRAM:31.8MB
# EPOCH[67/2000] loss:31.740 | F1:0.0048 | P:0.0025 | R:0.0504 | NDCG:0.0205 | T:20.49s | RAM:2581.0MB | CPU:21.8% | VRAM:31.8MB
# EPOCH[68/2000] loss:30.440 | F1:0.0051 | P:0.0027 | R:0.0532 | NDCG:0.0217 | T:20.63s | RAM:2573.6MB | CPU:22.4% | VRAM:31.8MB
# EPOCH[69/2000] loss:29.975 | F1:0.0050 | P:0.0026 | R:0.0529 | NDCG:0.0212 | T:20.65s | RAM:2568.0MB | CPU:23.1% | VRAM:31.8MB
# EPOCH[70/2000] loss:32.011 | F1:0.0049 | P:0.0026 | R:0.0515 | NDCG:0.0206 | T:20.68s | RAM:2571.8MB | CPU:21.9% | VRAM:31.8MB
# EPOCH[71/2000] loss:32.548 | F1:0.0051 | P:0.0027 | R:0.0536 | NDCG:0.0220 | T:20.88s | RAM:2575.8MB | CPU:22.4% | VRAM:31.8MB
# EPOCH[72/2000] loss:31.168 | F1:0.0048 | P:0.0025 | R:0.0507 | NDCG:0.0208 | T:20.67s | RAM:2574.7MB | CPU:22.7% | VRAM:31.8MB
# EPOCH[73/2000] loss:32.858 | F1:0.0048 | P:0.0025 | R:0.0507 | NDCG:0.0209 | T:20.58s | RAM:2585.1MB | CPU:21.9% | VRAM:31.8MB
# EPOCH[74/2000] loss:31.767 | F1:0.0048 | P:0.0025 | R:0.0507 | NDCG:0.0205 | T:20.62s | RAM:2582.2MB | CPU:21.9% | VRAM:31.8MB
# ##########################################
# Early stop is triggered at 74 epochs.
# Results:
# best epoch = 59, best recall = 0.05405405405405406, best ndcg = 0.021551430517140556
# The best model is saved at ./ultragcn_gitstar.pt
#
# Training finished. Total time: 00:26:16
# END
